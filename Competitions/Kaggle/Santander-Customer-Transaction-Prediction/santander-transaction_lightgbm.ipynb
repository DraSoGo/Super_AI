# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/santander-customer-transaction-prediction/sample_submission.csv
# /kaggle/input/santander-customer-transaction-prediction/train.csv
# /kaggle/input/santander-customer-transaction-prediction/test.csv

# %% [markdown]
# # **Library**

# %%
# !pip install autogluon.tabular
# Out:
# Collecting autogluon.tabular
#   Downloading autogluon_tabular-1.5.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (1.26.4)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (1.15.3)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (2.2.3)
# Collecting scikit-learn<1.8.0,>=1.4.0 (from autogluon.tabular)
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.tabular) (3.5)
# Collecting autogluon.core==1.5.0 (from autogluon.tabular)
#   Downloading autogluon_core-1.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting autogluon.features==1.5.0 (from autogluon.tabular)
#   Downloading autogluon_features-1.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tqdm<5,>=4.38 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.5.0->autogluon.tabular) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.5.0->autogluon.tabular) (2.32.5)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.5.0->autogluon.tabular) (3.7.2)
# Requirement already satisfied: boto3<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from autogluon.core==1.5.0->autogluon.tabular) (1.40.61)
# Collecting autogluon.common==1.5.0 (from autogluon.core==1.5.0->autogluon.tabular)
#   Downloading autogluon_common-1.5.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (19.0.1)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (7.1.3)
# Requirement already satisfied: joblib<1.7,>=1.2 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (1.5.2)
# Requirement already satisfied: pyyaml>=5.0 in /usr/local/lib/python3.11/dist-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (6.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.4.0,>=1.25.0->autogluon.tabular) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.tabular) (3.6.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.61 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (1.40.61)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->autogluon.tabular) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.4.0,>=1.25.0->autogluon.tabular) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.4.0,>=1.25.0->autogluon.tabular) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.4.0,>=1.25.0->autogluon.tabular) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.4.0,>=1.25.0->autogluon.tabular) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.4.0,>=1.25.0->autogluon.tabular) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (2025.10.5)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.4.0,>=1.25.0->autogluon.tabular) (2024.2.0)
# Downloading autogluon_tabular-1.5.0-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 13.6 MB/s eta 0:00:0000:01
# Downloading autogluon_core-1.5.0-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 18.5 MB/s eta 0:00:00
# Downloading autogluon_features-1.5.0-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 7.7 MB/s eta 0:00:00
# Downloading autogluon_common-1.5.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 kB 5.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 99.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: scikit-learn, autogluon.common, autogluon.features, autogluon.core, autogluon.tabular
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.2 which is incompatible.
# Successfully installed autogluon.common-1.5.0 autogluon.core-1.5.0 autogluon.features-1.5.0 autogluon.tabular-1.5.0 scikit-learn-1.7.2

# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import StratifiedKFold
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Explore Data**

# %%
train_df = pd.read_csv("/kaggle/input/santander-customer-transaction-prediction/train.csv")
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
test_df = pd.read_csv("/kaggle/input/santander-customer-transaction-prediction/test.csv")
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
train_df['var_0'].value_counts()
# Out:
# var_0
# 13.0656    11
# 8.6649     11
# 10.6829    11
# 9.5114     10
# 10.9468    10
#            ..
# 9.1800      1
# 7.3502      1
# 11.5106     1
# 14.5987     1
# 14.1869     1
# Name: count, Length: 94672, dtype: int64

# %% [markdown]
# # **Analyze Data**

# %% [markdown]
# ## **Distribution**

# %%
def plot_feature_distribution(df1, df2, label1, label2, features):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(10,10,figsize=(18,22))

    for feature in features:
        i += 1
        plt.subplot(10,10,i)
        sns.kdeplot(df1[feature],label=label1)
        sns.kdeplot(df2[feature],label=label2)
        plt.xlabel(feature, fontsize=9)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=6, pad=-6)
        plt.tick_params(axis='y', which='major', labelsize=6)
        plt.legend()
    plt.show()

# %% [markdown]
# ### Data 0,1

# %%
t0 = train_df.loc[train_df['target'] == 0]
t1 = train_df.loc[train_df['target'] == 1]
features = train_df.columns.values[2:102]
plot_feature_distribution(t0, t1, '0', '1', features)

# %%
features = train_df.columns.values[102:202]
plot_feature_distribution(t0, t1, '0', '1', features)

# %% [markdown]
# ### Data train,test

# %%
features = train_df.columns.values[2:102]
plot_feature_distribution(train_df, test_df, 'train', 'test', features)

# %%
features = train_df.columns.values[102:202]
plot_feature_distribution(train_df, test_df, 'train', 'test', features)

# %% [markdown]
# ### Mean

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].mean(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].mean(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].mean(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].mean(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].mean(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].mean(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].mean(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].mean(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ### Standard deviation

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].std(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].std(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].std(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].std(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].std(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].std(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].std(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].std(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ### Min

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].min(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].min(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].min(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].min(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].min(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].min(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].min(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].min(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ### Max

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].max(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].max(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].max(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].max(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].max(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].max(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].max(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].max(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ### Skew

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].skew(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].skew(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].skew(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].skew(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].skew(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].skew(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].skew(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].skew(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ### Kurtosis

# %%
plt.figure()
fig,ax = plt.subplots(2,2,figsize=(20,12))
features = train_df.columns.values[2:202]
plt.subplot(2,2,1)
plt.title('Column Train and Test')
sns.histplot(data = train_df[features].kurtosis(axis = 1), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].kurtosis(axis = 1), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,2)
plt.title('Column 1 and 0')
sns.histplot(data = t1[features].kurtosis(axis = 1), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].kurtosis(axis = 1), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,3)
plt.title('Row Train and Test')
sns.histplot(data = train_df[features].kurtosis(axis = 0), label = 'Train', kde = True,bins=120,stat="density")
sns.histplot(data = test_df[features].kurtosis(axis = 0), label = 'Test', kde = True,bins=120,stat="density")
plt.legend()
plt.subplot(2,2,4)
plt.title('Row 1 and 0')
sns.histplot(data = t1[features].kurtosis(axis = 0), label = '1', kde = True,bins=120,stat="density")
sns.histplot(data = t0[features].kurtosis(axis = 0), label = '0', kde = True,bins=120,stat="density")
plt.legend()
plt.show()

# %% [markdown]
# ## **Check Data**

# %% [markdown]
# ### Check Balance

# %%
sns.countplot(x="target",data = train_df, palette='Set3')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ### Check Duplicates

# %%
features = train_df.columns.values[2:202]
max_train = []
max_test = []
for i in features:
    frequency = train_df[i].value_counts()
    max_train.append([i,frequency.max(),frequency.idxmax()])
    frequency = test_df[i].value_counts()
    max_test.append([i,frequency.max(),frequency.idxmax()])
max_train = pd.DataFrame(max_train,columns=["feature","max dup","value"]).sort_values(by="max dup",ascending=False)
max_test = pd.DataFrame(max_test,columns=["feature","max dup","value"]).sort_values(by="max dup",ascending=False)

# %%
max_train.head(10)
# Out:
#      feature  max dup    value
# 68    var_68     1084   5.0214
# 108  var_108      313  14.1999
# 126  var_126      305  11.5356
# 12    var_12      203  13.5545
# 91    var_91       66   6.9919
# 103  var_103       61   1.6662
# 148  var_148       59   4.0456
# 71    var_71       54   0.7031
# 161  var_161       52   5.7688
# 25    var_25       41  13.6723

# %%
max_test.head(10)
# Out:
#      feature  max dup    value
# 68    var_68     1104   5.0197
# 126  var_126      307  11.5357
# 108  var_108      302  14.1999
# 12    var_12      188  13.5546
# 91    var_91       86   6.9939
# 103  var_103       78   1.4659
# 148  var_148       74   4.0004
# 161  var_161       69   5.7114
# 25    var_25       60  13.5965
# 71    var_71       60   0.5389

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ## **Correlation**

# %%
corr = train_df[features].corr().abs().unstack().sort_values().reset_index()
corr = corr[corr['level_0'] != corr['level_1']]

# %%
corr.head()
# Out:
#    level_0  level_1             0
# 0  var_191   var_75  2.703975e-08
# 1   var_75  var_191  2.703975e-08
# 2  var_173    var_6  5.942735e-08
# 3    var_6  var_173  5.942735e-08
# 4  var_126  var_109  1.313947e-07

# %%
corr.tail()
# Out:
#        level_0  level_1         0
# 39795   var_81  var_165  0.009714
# 39796   var_53  var_148  0.009788
# 39797  var_148   var_53  0.009788
# 39798  var_139   var_26  0.009844
# 39799   var_26  var_139  0.009844

# %% [markdown]
# ## **Make Features**

# %%
features = train_df.columns.values[2:202]
for df in [train_df, test_df]:
    df['sum'] = df[features].sum(axis=1)
    df['mean'] = df[features].mean(axis=1)
    df['min'] = df[features].min(axis=1)
    df['max'] = df[features].max(axis=1)
    df['std'] = df[features].std(axis=1)
    df['kurt'] = df[features].kurtosis(axis=1)
    df['skew'] = df[features].skew(axis=1)

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_197  var_198  var_199        sum      mean      min  \
# 0  18.6266  ...   8.5635  12.7803  -1.0914  1456.3182  7.281591 -21.4494
# 1  16.5338  ...   8.7889  18.3560   1.9518  1415.3636  7.076818 -47.3797
# 2  14.6155  ...   8.2675  14.7222   0.3965  1240.8966  6.204483 -22.4038
# 3  14.9250  ...  10.2922  17.9697  -8.9996  1288.2319  6.441159 -35.1659
# 4  19.2514  ...   9.5031  17.9974  -8.8104  1354.2310  6.771155 -65.4863
#
#        max        std      kurt      skew
# 0  43.1127   9.331540  1.331023  0.101580
# 1  40.5632  10.336130  4.110215 -0.351734
# 2  33.8820   8.753387  0.546438 -0.056957
# 3  38.1015   9.594064  2.630499 -0.480116
# 4  41.1037  11.287122  9.787399 -1.463426
#
# [5 rows x 209 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_197  var_198  var_199        sum      mean  \
# 0  18.2675  2.1337  ...  10.7200  15.4722  -8.7197  1416.6404  7.083202
# 1  18.6316 -4.4131  ...   9.8714  19.1293 -20.9760  1249.6860  6.248430
# 2  20.2537  1.5233  ...   7.0618  19.8956 -23.1794  1430.2599  7.151299
# 3  20.5660  3.3755  ...   9.2295  13.0168  -4.2108  1411.4447  7.057223
# 4  10.6048  2.9890  ...   7.2882  13.9260  -9.1846  1423.7364  7.118682
#
#        min      max        std      kurt      skew
# 0 -31.9891  42.0248   9.910632  1.871262 -0.088518
# 1 -41.1924  35.6020   9.541267  3.391068 -0.559785
# 2 -34.3488  39.3654   9.967466  2.326901 -0.135084
# 3 -21.4797  40.3383   8.257204  2.253054 -0.167741
# 4 -24.8254  45.5510  10.043542  2.044943  0.293484
#
# [5 rows x 208 columns]

# %% [markdown]
# # **Model**

# %%
features = train_df.columns.values[2:]
target = train_df['target']

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.4,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.01,
    'max_depth': -1,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': 1
}

# %%
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=44000)

oof = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df.values, target.values)):
    print("Fold {}".format(fold_))
    
    trn_data = lgb.Dataset(train_df.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df.iloc[val_idx][features], label=target.iloc[val_idx])

    num_round = 1000000
    callbacks = [
        lgb.log_evaluation(period=1000),
        lgb.early_stopping(stopping_rounds=3000)
    ]
    clf = lgb.train(
        param, 
        trn_data, 
        num_round, 
        valid_sets=[trn_data, val_data], 
        callbacks=callbacks
    )
    oof[val_idx] = clf.predict(train_df.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test_df[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# Fold 0
# [LightGBM] [Info] Number of positive: 18089, number of negative: 161911
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.148750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.888564	valid_1's auc: 0.873932
# [2000]	training's auc: 0.905497	valid_1's auc: 0.886261
# [3000]	training's auc: 0.915795	valid_1's auc: 0.892713
# [4000]	training's auc: 0.923134	valid_1's auc: 0.896238
# [5000]	training's auc: 0.928664	valid_1's auc: 0.898181
# [6000]	training's auc: 0.933368	valid_1's auc: 0.899283
# [7000]	training's auc: 0.937611	valid_1's auc: 0.899891
# [8000]	training's auc: 0.941565	valid_1's auc: 0.900182
# [9000]	training's auc: 0.94521	valid_1's auc: 0.900534
# [10000]	training's auc: 0.948604	valid_1's auc: 0.90061
# [11000]	training's auc: 0.951814	valid_1's auc: 0.900682
# [12000]	training's auc: 0.954946	valid_1's auc: 0.900658
# [13000]	training's auc: 0.957916	valid_1's auc: 0.900627
# [14000]	training's auc: 0.960763	valid_1's auc: 0.900461
# [15000]	training's auc: 0.963479	valid_1's auc: 0.900513
# Early stopping, best iteration is:
# [12276]	training's auc: 0.955781	valid_1's auc: 0.900739
# Fold 1
# [LightGBM] [Info] Number of positive: 18089, number of negative: 161911
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.160334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.888063	valid_1's auc: 0.865366
# [2000]	training's auc: 0.905574	valid_1's auc: 0.881506
# [3000]	training's auc: 0.915787	valid_1's auc: 0.889138
# [4000]	training's auc: 0.92309	valid_1's auc: 0.89349
# [5000]	training's auc: 0.92865	valid_1's auc: 0.89606
# [6000]	training's auc: 0.933404	valid_1's auc: 0.897707
# [7000]	training's auc: 0.937655	valid_1's auc: 0.8986
# [8000]	training's auc: 0.941517	valid_1's auc: 0.899235
# [9000]	training's auc: 0.945169	valid_1's auc: 0.899555
# [10000]	training's auc: 0.948521	valid_1's auc: 0.899688
# [11000]	training's auc: 0.951801	valid_1's auc: 0.899879
# [12000]	training's auc: 0.954981	valid_1's auc: 0.900063
# [13000]	training's auc: 0.9579	valid_1's auc: 0.90007
# [14000]	training's auc: 0.960643	valid_1's auc: 0.90025
# [15000]	training's auc: 0.963315	valid_1's auc: 0.900332
# [16000]	training's auc: 0.965868	valid_1's auc: 0.90046
# [17000]	training's auc: 0.968293	valid_1's auc: 0.900338
# [18000]	training's auc: 0.970594	valid_1's auc: 0.900419
# Early stopping, best iteration is:
# [15899]	training's auc: 0.965629	valid_1's auc: 0.90053
# Fold 2
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.88867	valid_1's auc: 0.869641
# [2000]	training's auc: 0.905861	valid_1's auc: 0.884415
# [3000]	training's auc: 0.916002	valid_1's auc: 0.891351
# [4000]	training's auc: 0.923268	valid_1's auc: 0.895416
# [5000]	training's auc: 0.928761	valid_1's auc: 0.897662
# [6000]	training's auc: 0.933503	valid_1's auc: 0.898556
# [7000]	training's auc: 0.937719	valid_1's auc: 0.899142
# [8000]	training's auc: 0.941529	valid_1's auc: 0.899599
# [9000]	training's auc: 0.945205	valid_1's auc: 0.899745
# [10000]	training's auc: 0.948664	valid_1's auc: 0.899903
# [11000]	training's auc: 0.951934	valid_1's auc: 0.899607
# [12000]	training's auc: 0.955042	valid_1's auc: 0.899627
# Early stopping, best iteration is:
# [9687]	training's auc: 0.947572	valid_1's auc: 0.899944
# Fold 3
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.148253 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.888954	valid_1's auc: 0.86882
# [2000]	training's auc: 0.905894	valid_1's auc: 0.88312
# [3000]	training's auc: 0.91606	valid_1's auc: 0.889856
# [4000]	training's auc: 0.923216	valid_1's auc: 0.893652
# [5000]	training's auc: 0.92877	valid_1's auc: 0.895979
# [6000]	training's auc: 0.933541	valid_1's auc: 0.897592
# [7000]	training's auc: 0.937727	valid_1's auc: 0.898275
# [8000]	training's auc: 0.941605	valid_1's auc: 0.898662
# [9000]	training's auc: 0.945228	valid_1's auc: 0.89912
# [10000]	training's auc: 0.948609	valid_1's auc: 0.89962
# [11000]	training's auc: 0.951875	valid_1's auc: 0.899565
# [12000]	training's auc: 0.955049	valid_1's auc: 0.899417
# [13000]	training's auc: 0.957982	valid_1's auc: 0.89936
# Early stopping, best iteration is:
# [10098]	training's auc: 0.948938	valid_1's auc: 0.899678
# Fold 4
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.889255	valid_1's auc: 0.865777
# [2000]	training's auc: 0.906539	valid_1's auc: 0.879092
# [3000]	training's auc: 0.916597	valid_1's auc: 0.885941
# [4000]	training's auc: 0.92375	valid_1's auc: 0.889824
# [5000]	training's auc: 0.929283	valid_1's auc: 0.891896
# [6000]	training's auc: 0.933978	valid_1's auc: 0.893035
# [7000]	training's auc: 0.938102	valid_1's auc: 0.893712
# [8000]	training's auc: 0.941964	valid_1's auc: 0.894266
# [9000]	training's auc: 0.945582	valid_1's auc: 0.894538
# [10000]	training's auc: 0.948999	valid_1's auc: 0.894757
# [11000]	training's auc: 0.952217	valid_1's auc: 0.894858
# [12000]	training's auc: 0.955279	valid_1's auc: 0.894609
# [13000]	training's auc: 0.95823	valid_1's auc: 0.89456
# Early stopping, best iteration is:
# [10576]	training's auc: 0.950897	valid_1's auc: 0.894919
# Fold 5
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.888784	valid_1's auc: 0.871126
# [2000]	training's auc: 0.905658	valid_1's auc: 0.883755
# [3000]	training's auc: 0.916008	valid_1's auc: 0.890226
# [4000]	training's auc: 0.923286	valid_1's auc: 0.893823
# [5000]	training's auc: 0.928807	valid_1's auc: 0.895861
# [6000]	training's auc: 0.933599	valid_1's auc: 0.89709
# [7000]	training's auc: 0.937776	valid_1's auc: 0.89783
# [8000]	training's auc: 0.941639	valid_1's auc: 0.898366
# [9000]	training's auc: 0.945305	valid_1's auc: 0.898688
# [10000]	training's auc: 0.94866	valid_1's auc: 0.899005
# [11000]	training's auc: 0.951934	valid_1's auc: 0.899031
# [12000]	training's auc: 0.95505	valid_1's auc: 0.899204
# [13000]	training's auc: 0.957981	valid_1's auc: 0.898907
# [14000]	training's auc: 0.960778	valid_1's auc: 0.898775
# Early stopping, best iteration is:
# [11808]	training's auc: 0.954462	valid_1's auc: 0.89922
# Fold 6
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144863 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.889154	valid_1's auc: 0.867609
# [2000]	training's auc: 0.905911	valid_1's auc: 0.882181
# [3000]	training's auc: 0.916019	valid_1's auc: 0.888918
# [4000]	training's auc: 0.923394	valid_1's auc: 0.893256
# [5000]	training's auc: 0.928943	valid_1's auc: 0.895436
# [6000]	training's auc: 0.933647	valid_1's auc: 0.89651
# [7000]	training's auc: 0.937851	valid_1's auc: 0.89721
# [8000]	training's auc: 0.941732	valid_1's auc: 0.898166
# [9000]	training's auc: 0.945326	valid_1's auc: 0.898607
# [10000]	training's auc: 0.948823	valid_1's auc: 0.898978
# [11000]	training's auc: 0.952041	valid_1's auc: 0.899083
# [12000]	training's auc: 0.95515	valid_1's auc: 0.899025
# [13000]	training's auc: 0.958107	valid_1's auc: 0.898875
# [14000]	training's auc: 0.960923	valid_1's auc: 0.898891
# Early stopping, best iteration is:
# [11379]	training's auc: 0.953256	valid_1's auc: 0.899142
# Fold 7
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.180173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.888259	valid_1's auc: 0.874569
# [2000]	training's auc: 0.905539	valid_1's auc: 0.887406
# [3000]	training's auc: 0.915614	valid_1's auc: 0.893888
# [4000]	training's auc: 0.922874	valid_1's auc: 0.897767
# [5000]	training's auc: 0.928405	valid_1's auc: 0.899531
# [6000]	training's auc: 0.933061	valid_1's auc: 0.900773
# [7000]	training's auc: 0.937284	valid_1's auc: 0.901383
# [8000]	training's auc: 0.941135	valid_1's auc: 0.901947
# [9000]	training's auc: 0.94472	valid_1's auc: 0.902352
# [10000]	training's auc: 0.948145	valid_1's auc: 0.902545
# [11000]	training's auc: 0.951427	valid_1's auc: 0.90259
# [12000]	training's auc: 0.954597	valid_1's auc: 0.902556
# [13000]	training's auc: 0.957564	valid_1's auc: 0.902591
# [14000]	training's auc: 0.960367	valid_1's auc: 0.902488
# [15000]	training's auc: 0.963019	valid_1's auc: 0.902406
# [16000]	training's auc: 0.965583	valid_1's auc: 0.902443
# Early stopping, best iteration is:
# [13727]	training's auc: 0.959624	valid_1's auc: 0.902693
# Fold 8
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.889293	valid_1's auc: 0.868117
# [2000]	training's auc: 0.906309	valid_1's auc: 0.880959
# [3000]	training's auc: 0.916552	valid_1's auc: 0.887062
# [4000]	training's auc: 0.923733	valid_1's auc: 0.890709
# [5000]	training's auc: 0.929269	valid_1's auc: 0.892611
# [6000]	training's auc: 0.933915	valid_1's auc: 0.893834
# [7000]	training's auc: 0.938081	valid_1's auc: 0.89474
# [8000]	training's auc: 0.94196	valid_1's auc: 0.895128
# [9000]	training's auc: 0.945492	valid_1's auc: 0.895499
# [10000]	training's auc: 0.948947	valid_1's auc: 0.895684
# [11000]	training's auc: 0.952155	valid_1's auc: 0.895732
# [12000]	training's auc: 0.955278	valid_1's auc: 0.89574
# [13000]	training's auc: 0.958175	valid_1's auc: 0.895829
# [14000]	training's auc: 0.960916	valid_1's auc: 0.895814
# [15000]	training's auc: 0.963568	valid_1's auc: 0.895785
# [16000]	training's auc: 0.966121	valid_1's auc: 0.895341
# Early stopping, best iteration is:
# [13752]	training's auc: 0.960252	valid_1's auc: 0.895878
# Fold 9
# [LightGBM] [Info] Number of positive: 18088, number of negative: 161912
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.151533 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 52785
# [LightGBM] [Info] Number of data points in the train set: 180000, number of used features: 207
# Training until validation scores don't improve for 3000 rounds
# [1000]	training's auc: 0.887553	valid_1's auc: 0.878256
# [2000]	training's auc: 0.905254	valid_1's auc: 0.891489
# [3000]	training's auc: 0.915518	valid_1's auc: 0.897936
# [4000]	training's auc: 0.922986	valid_1's auc: 0.901491
# [5000]	training's auc: 0.928634	valid_1's auc: 0.902976
# [6000]	training's auc: 0.933315	valid_1's auc: 0.903629
# [7000]	training's auc: 0.937586	valid_1's auc: 0.904059
# [8000]	training's auc: 0.941437	valid_1's auc: 0.904485
# [9000]	training's auc: 0.945108	valid_1's auc: 0.904723
# [10000]	training's auc: 0.948546	valid_1's auc: 0.904596
# [11000]	training's auc: 0.951799	valid_1's auc: 0.904715
# [12000]	training's auc: 0.954921	valid_1's auc: 0.904818
# [13000]	training's auc: 0.957883	valid_1's auc: 0.90468
# [14000]	training's auc: 0.96069	valid_1's auc: 0.904656
# [15000]	training's auc: 0.963362	valid_1's auc: 0.904483
# Early stopping, best iteration is:
# [12388]	training's auc: 0.956101	valid_1's auc: 0.90492
# CV score: 0.89969

# %% [markdown]
# # **Evaluation**

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:150].index)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,28))
sns.barplot(x="importance", y="Feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('Features importance (averaged/folds)')
plt.tight_layout()
plt.savefig('FI.png')

# %% [markdown]
# # **Submission**

# %%
submission = pd.DataFrame({"ID_code":test_df["ID_code"].values})
submission["target"] = predictions
submission['target'] = round(submission['target']).astype(int)

# %%
submission.head()
# Out:
#   ID_code  target
# 0  test_0       0
# 1  test_1       0
# 2  test_2       0
# 3  test_3       0
# 4  test_4       0

# %%
sns.countplot(x="target",data = submission, palette='Set3')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
submission.to_csv('submission.csv', index=False)
